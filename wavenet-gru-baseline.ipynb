# %% [markdown]
# # Comments
#
# Thanks to this amazing scripts
#
# * https://www.kaggle.com/xhlulu/openvaccine-simple-gru-model
# * https://www.kaggle.com/tuckerarrants/openvaccine-gru-lstm
#
# This is just an experiment :)

# %%
import warnings
warnings.filterwarnings('ignore')
import os
import pandas as pd
import numpy as np
import seaborn as sns
import math
import random
import json
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import tensorflow as tf
import tensorflow_addons as tfa
import tensorflow.keras.backend as K
from sklearn.model_selection import train_test_split, KFold
from sklearn import metrics

# %% [markdown]
# # Important
# From the data description tab, we must predict multiple ground truths in this competition, 5 to be exact. While the submission requires all 5, only 3 are scored: reactivity, deg_Mg_pH10 and deg_Mg_50C
#
# Lengths:
#
# Train and Public Test:
#
# * sequence, structure and predicted_loop_type have a length of 107
# * reactivity, deg_Mg_pH10, deg_pH10, deg_Mg_50C and deg_50C have a length of 68
#
# Private Test:
#
# * sequence, structure and predicted_loop_type have a length of 130
# * reactivity, deg_Mg_pH10, deg_pH10, deg_Mg_50C and deg_50C have a length of 91
#
# To build the public test they use a filter (SN_filter = 1). They did not use this filter for the private so using this filter may overfitt the public leaderboard?

# %%
# Basic training configurations
# Number of folds for KFold validation strategy
FOLDS = 5
# Number of epochs to train each model
EPOCHS = 130
# Batch size
BATCH_SIZE = 64
# Learning rate
LR = 0.001
# Verbosity
VERBOSE = 2
# Seed for deterministic results
SEED = 123

# Function to seed everything
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)
    
seed_everything(SEED)

# Read training, test and sample submission data
train = pd.read_json('../input/stanford-covid-vaccine/train.json', lines = True)
test = pd.read_json('../input/stanford-covid-vaccine/test.json', lines = True)
sample_sub = pd.read_csv('../input/stanford-covid-vaccine/sample_submission.csv')


# Target column list
target_cols = ['reactivity', 'deg_Mg_pH10', 'deg_pH10', 'deg_Mg_50C', 'deg_50C']

# Dictionary comprehension to map the token with an specific id
token2int = {x: i for i, x in enumerate('().ACGUBEHIMSX')}

# Preprocesing function to transform features to 3d format
def preprocess_inputs(df, cols = ['sequence', 'structure', 'predicted_loop_type']):
    return np.transpose(
        np.array(
            df[cols]\
            .applymap(lambda seq: [token2int[x] for x in seq])\
            .values\
            .tolist()
        ),
        (0, 2, 1)
    )

# Transform training feature sequences to a 3d matrix of (x, 107, 3)
train_inputs = preprocess_inputs(train)
# Transform training targets sequences to a 3d matrix of (x, 68, 5)
train_labels = np.array(train[target_cols].values.tolist()).transpose(0, 2, 1)
# Get different test sets
public_test_df = test[test['seq_length'] == 107]
private_test_df = test[test['seq_length'] == 130]
# Preprocess the test sets to the same format as our training data
public_test = preprocess_inputs(public_test_df)
private_test = preprocess_inputs(private_test_df)

# %%
# Custom loss_fnc, extracted from https://www.kaggle.com/c/stanford-covid-vaccine/discussion/183211
def CMCRMSE(y_true, y_pred):
    colwise_mse = tf.reduce_mean(tf.square(y_true - y_pred), axis=1)
    return tf.reduce_mean(tf.sqrt(colwise_mse), axis=1)


# Function to build our wave net model
def build_model(seq_len = 107, pred_len = 68, embed_dim = 100, dropout = 0.30):
    
    def wave_block(x, filters, kernel_size, n):
        dilation_rates = [2 ** i for i in range(n)]
        x = tf.keras.layers.Conv1D(filters = filters, 
                                   kernel_size = 1,
                                   padding = 'same')(x)
        res_x = x
        for dilation_rate in dilation_rates:
            tanh_out = tf.keras.layers.Conv1D(filters = filters,
                              kernel_size = kernel_size,
                              padding = 'same', 
                              activation = 'tanh', 
                              dilation_rate = dilation_rate)(x)
            sigm_out = tf.keras.layers.Conv1D(filters = filters,
                              kernel_size = kernel_size,
                              padding = 'same',
                              activation = 'sigmoid', 
                              dilation_rate = dilation_rate)(x)
            x = tf.keras.layers.Multiply()([tanh_out, sigm_out])
            x = tf.keras.layers.Conv1D(filters = filters,
                       kernel_size = 1,
                       padding = 'same')(x)
            res_x = tf.keras.layers.Add()([res_x, x])
        return res_x
    
    inputs = tf.keras.layers.Input(shape = (seq_len, 3))
    embed = tf.keras.layers.Embedding(input_dim = len(token2int), output_dim = embed_dim)(inputs)
    reshaped = tf.reshape(embed, shape = (-1, embed.shape[1], embed.shape[2] * embed.shape[3]))
    x = tf.keras.layers.SpatialDropout1D(dropout)(reshaped)
    
    '''x = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(128, 
                                                          dropout = dropout, 
                                                          return_sequences = True, 
                                                          kernel_initializer = 'orthogonal'))(reshaped)'''
    x = wave_block(x, 64, 3, 8)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    x = wave_block(x, 128, 3, 6)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    x = wave_block(x, 256, 3, 4)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout)(x)
    
    x = wave_block(x, 512, 3, 1)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout)(x)
    
    
    truncated = x[:, :pred_len]
    out = tf.keras.layers.Dense(5, activation = 'linear')(truncated)
    model = tf.keras.models.Model(inputs = inputs, outputs = out)
    opt = tf.keras.optimizers.Adam(learning_rate = LR)
    opt = tfa.optimizers.SWA(opt)
    model.compile(optimizer = opt,
                  loss = tf.keras.losses.MeanSquaredLogarithmicError(),
                  metrics = [tf.keras.metrics.RootMeanSquaredError()])
    
    return model

# Evaluation metric for this problem (mean columnwise root mean squared error)
def mcrmse(y_true, y_pred):
    y_true_ = y_true.reshape(163200, 5)
    y_pred_ = y_pred.reshape(163200, 5)
    y_true0 = y_true_[:, 0]
    y_true1 = y_true_[:, 1]
    y_true2 = y_true_[:, 2]
    y_true3 = y_true_[:, 3]
    y_true4 = y_true_[:, 4]
    y_pred0 = y_pred_[:, 0]
    y_pred1 = y_pred_[:, 1]
    y_pred2 = y_pred_[:, 2]
    y_pred3 = y_pred_[:, 3]
    y_pred4 = y_pred_[:, 4]
    rmse0 = math.sqrt(metrics.mean_squared_error(y_true0, y_pred0))
    rmse1 = math.sqrt(metrics.mean_squared_error(y_true1, y_pred1))
    rmse2 = math.sqrt(metrics.mean_squared_error(y_true2, y_pred2))
    rmse3 = math.sqrt(metrics.mean_squared_error(y_true3, y_pred3))
    rmse4 = math.sqrt(metrics.mean_squared_error(y_true4, y_pred4))
    return np.mean([rmse0, rmse1, rmse2, rmse3, rmse4])


def train_and_evaluate(train_inputs, train_labels, public_test, private_test):
        
    oof_preds = np.zeros((train_inputs.shape[0], 68, 5))
    public_preds = np.zeros((public_test.shape[0], 107, 5))
    private_preds = np.zeros((private_test.shape[0], 130, 5))

    kfold = KFold(FOLDS, shuffle = True, random_state = SEED)
    for fold, (train_index, val_index) in enumerate(kfold.split(train_inputs)):
        
        print(f'Training fold {fold + 1}')
    
        checkpoint = tf.keras.callbacks.ModelCheckpoint(f'fold_{fold + 1}.h5', 
                                                        monitor = 'val_loss',
                                                        save_best_only = True,
                                                        save_weights_only = True
                                                       )
        # Using learning rate scheduler
        cb_lr_schedule = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss', 
                                                              mode = 'min', 
                                                              factor = 0.5, 
                                                              patience = 5, 
                                                              verbose = 1, 
                                                              min_delta = 0.00001
                                                             )
    
        x_train, x_val = train_inputs[train_index], train_inputs[val_index]
        y_train, y_val = train_labels[train_index], train_labels[val_index]
        K.clear_session()
        # Build a truncated model based on train target lengths
        model = build_model()
        history = model.fit(x_train, y_train,
                            validation_data = (x_val, y_val),
                            batch_size = BATCH_SIZE,
                            epochs = EPOCHS,
                            callbacks = [checkpoint, cb_lr_schedule],
                            verbose = VERBOSE)
    
        # Load best model to predict the validation set
        model.load_weights(f'fold_{fold + 1}.h5')
        oof_preds[val_index] = model.predict(x_val)

        # Load best model and predict the entire test sequence for the public test
        short = build_model(seq_len = 107, pred_len = 107)
        short.load_weights(f'fold_{fold + 1}.h5')
        public_preds += short.predict(public_test) / FOLDS

        # Load best model and predict the entire test sequence for the private test
        long = build_model(seq_len = 130, pred_len = 130)
        long.load_weights(f'fold_{fold + 1}.h5')
        private_preds += long.predict(private_test) / FOLDS
        
        print('-'*50)
        print('\n')
    
    # Calculate out of folds predictions
    mean_col_rmse = mcrmse(train_labels, oof_preds)

    print(f'Our out of folds mean columnwise root mean squared error is {mean_col_rmse}')
    
    return public_preds, private_preds, oof_preds

# %%
public_preds, private_preds, oof_preds = train_and_evaluate(train_inputs, train_labels, public_test, private_test)
# Out:
# Training fold 1
# Epoch 1/130
# 30/30 - 5s - loss: 0.1539 - root_mean_squared_error: 1.9096 - val_loss: 0.1700 - val_root_mean_squared_error: 2.2366
# Epoch 2/130
# 30/30 - 3s - loss: 0.0742 - root_mean_squared_error: 1.0396 - val_loss: 0.1046 - val_root_mean_squared_error: 1.0111
# Epoch 3/130
# 30/30 - 3s - loss: 0.0567 - root_mean_squared_error: 0.9172 - val_loss: 0.0791 - val_root_mean_squared_error: 0.9301
# Epoch 4/130
# 30/30 - 3s - loss: 0.0535 - root_mean_squared_error: 0.9107 - val_loss: 0.0696 - val_root_mean_squared_error: 0.9138
# Epoch 5/130
# 30/30 - 3s - loss: 0.0511 - root_mean_squared_error: 0.9068 - val_loss: 0.0582 - val_root_mean_squared_error: 0.8941
# Epoch 6/130
# 30/30 - 3s - loss: 0.0494 - root_mean_squared_error: 0.9036 - val_loss: 0.0578 - val_root_mean_squared_error: 0.8939
# Epoch 7/130
# 30/30 - 3s - loss: 0.0476 - root_mean_squared_error: 0.8996 - val_loss: 0.0519 - val_root_mean_squared_error: 0.8824
# Epoch 8/130
# 30/30 - 3s - loss: 0.0461 - root_mean_squared_error: 0.8976 - val_loss: 0.0486 - val_root_mean_squared_error: 0.8769
# Epoch 9/130
# 30/30 - 3s - loss: 0.0447 - root_mean_squared_error: 0.8946 - val_loss: 0.0473 - val_root_mean_squared_error: 0.8761
# Epoch 10/130
# 30/30 - 3s - loss: 0.0440 - root_mean_squared_error: 0.8934 - val_loss: 0.0457 - val_root_mean_squared_error: 0.8729
# Epoch 11/130
# 30/30 - 3s - loss: 0.0428 - root_mean_squared_error: 0.8914 - val_loss: 0.0418 - val_root_mean_squared_error: 0.8647
# Epoch 12/130
# 30/30 - 3s - loss: 0.0417 - root_mean_squared_error: 0.8885 - val_loss: 0.0388 - val_root_mean_squared_error: 0.8620
# Epoch 13/130
# 30/30 - 3s - loss: 0.0412 - root_mean_squared_error: 0.8873 - val_loss: 0.0421 - val_root_mean_squared_error: 0.8657
# Epoch 14/130
# 30/30 - 3s - loss: 0.0401 - root_mean_squared_error: 0.8861 - val_loss: 0.0383 - val_root_mean_squared_error: 0.8597
# Epoch 15/130
# 30/30 - 3s - loss: 0.0392 - root_mean_squared_error: 0.8838 - val_loss: 0.0371 - val_root_mean_squared_error: 0.8586
# Epoch 16/130
# 30/30 - 3s - loss: 0.0387 - root_mean_squared_error: 0.8832 - val_loss: 0.0367 - val_root_mean_squared_error: 0.8589
# Epoch 17/130
# 30/30 - 3s - loss: 0.0382 - root_mean_squared_error: 0.8822 - val_loss: 0.0357 - val_root_mean_squared_error: 0.8552
# Epoch 18/130
# 30/30 - 3s - loss: 0.0377 - root_mean_squared_error: 0.8803 - val_loss: 0.0360 - val_root_mean_squared_error: 0.8529
# Epoch 19/130
# 30/30 - 3s - loss: 0.0370 - root_mean_squared_error: 0.8790 - val_loss: 0.0354 - val_root_mean_squared_error: 0.8545
# Epoch 20/130
# 30/30 - 3s - loss: 0.0365 - root_mean_squared_error: 0.8777 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8531
# Epoch 21/130
# 30/30 - 3s - loss: 0.0357 - root_mean_squared_error: 0.8764 - val_loss: 0.0346 - val_root_mean_squared_error: 0.8515
# Epoch 22/130
# 30/30 - 3s - loss: 0.0353 - root_mean_squared_error: 0.8748 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8526
# Epoch 23/130
# 30/30 - 3s - loss: 0.0347 - root_mean_squared_error: 0.8731 - val_loss: 0.0339 - val_root_mean_squared_error: 0.8510
# Epoch 24/130
# 30/30 - 3s - loss: 0.0346 - root_mean_squared_error: 0.8735 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8498
# Epoch 25/130
# 30/30 - 3s - loss: 0.0339 - root_mean_squared_error: 0.8711 - val_loss: 0.0334 - val_root_mean_squared_error: 0.8497
# Epoch 26/130
# 30/30 - 3s - loss: 0.0333 - root_mean_squared_error: 0.8690 - val_loss: 0.0333 - val_root_mean_squared_error: 0.8495
# Epoch 27/130
# 30/30 - 3s - loss: 0.0332 - root_mean_squared_error: 0.8676 - val_loss: 0.0346 - val_root_mean_squared_error: 0.8532
# Epoch 28/130
# 30/30 - 3s - loss: 0.0326 - root_mean_squared_error: 0.8679 - val_loss: 0.0347 - val_root_mean_squared_error: 0.8509
# Epoch 29/130
# 30/30 - 3s - loss: 0.0323 - root_mean_squared_error: 0.8654 - val_loss: 0.0332 - val_root_mean_squared_error: 0.8483
# Epoch 30/130
# 30/30 - 3s - loss: 0.0314 - root_mean_squared_error: 0.8624 - val_loss: 0.0335 - val_root_mean_squared_error: 0.8483
# Epoch 31/130
# 30/30 - 3s - loss: 0.0310 - root_mean_squared_error: 0.8606 - val_loss: 0.0332 - val_root_mean_squared_error: 0.8476
# Epoch 32/130
# 30/30 - 3s - loss: 0.0308 - root_mean_squared_error: 0.8594 - val_loss: 0.0337 - val_root_mean_squared_error: 0.8474
# Epoch 33/130
# 30/30 - 3s - loss: 0.0301 - root_mean_squared_error: 0.8566 - val_loss: 0.0334 - val_root_mean_squared_error: 0.8469
# Epoch 34/130
# 30/30 - 3s - loss: 0.0300 - root_mean_squared_error: 0.8555 - val_loss: 0.0329 - val_root_mean_squared_error: 0.8462
# Epoch 35/130
# 30/30 - 3s - loss: 0.0295 - root_mean_squared_error: 0.8542 - val_loss: 0.0333 - val_root_mean_squared_error: 0.8488
# Epoch 36/130
# 30/30 - 3s - loss: 0.0292 - root_mean_squared_error: 0.8514 - val_loss: 0.0329 - val_root_mean_squared_error: 0.8459
# Epoch 37/130
# 30/30 - 3s - loss: 0.0287 - root_mean_squared_error: 0.8500 - val_loss: 0.0330 - val_root_mean_squared_error: 0.8494
# Epoch 38/130
# 30/30 - 3s - loss: 0.0284 - root_mean_squared_error: 0.8486 - val_loss: 0.0335 - val_root_mean_squared_error: 0.8453
# Epoch 39/130
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 30/30 - 3s - loss: 0.0281 - root_mean_squared_error: 0.8469 - val_loss: 0.0334 - val_root_mean_squared_error: 0.8476
# Epoch 40/130
# 30/30 - 3s - loss: 0.0270 - root_mean_squared_error: 0.8420 - val_loss: 0.0326 - val_root_mean_squared_error: 0.8460
# Epoch 41/130
# 30/30 - 3s - loss: 0.0265 - root_mean_squared_error: 0.8400 - val_loss: 0.0322 - val_root_mean_squared_error: 0.8459
# Epoch 42/130
# 30/30 - 3s - loss: 0.0261 - root_mean_squared_error: 0.8367 - val_loss: 0.0331 - val_root_mean_squared_error: 0.8466
# Epoch 43/130
# 30/30 - 3s - loss: 0.0258 - root_mean_squared_error: 0.8351 - val_loss: 0.0334 - val_root_mean_squared_error: 0.8471
# Epoch 44/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8327 - val_loss: 0.0332 - val_root_mean_squared_error: 0.8479
# Epoch 45/130
# 30/30 - 3s - loss: 0.0254 - root_mean_squared_error: 0.8314 - val_loss: 0.0332 - val_root_mean_squared_error: 0.8481
# Epoch 46/130
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 30/30 - 3s - loss: 0.0251 - root_mean_squared_error: 0.8294 - val_loss: 0.0332 - val_root_mean_squared_error: 0.8491
# Epoch 47/130
# 30/30 - 3s - loss: 0.0245 - root_mean_squared_error: 0.8258 - val_loss: 0.0330 - val_root_mean_squared_error: 0.8486
# Epoch 48/130
# 30/30 - 3s - loss: 0.0242 - root_mean_squared_error: 0.8242 - val_loss: 0.0336 - val_root_mean_squared_error: 0.8516
# Epoch 49/130
# 30/30 - 3s - loss: 0.0240 - root_mean_squared_error: 0.8215 - val_loss: 0.0335 - val_root_mean_squared_error: 0.8511
# Epoch 50/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8204 - val_loss: 0.0329 - val_root_mean_squared_error: 0.8493
# Epoch 51/130
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 30/30 - 3s - loss: 0.0236 - root_mean_squared_error: 0.8193 - val_loss: 0.0330 - val_root_mean_squared_error: 0.8500
# Epoch 52/130
# 30/30 - 3s - loss: 0.0232 - root_mean_squared_error: 0.8145 - val_loss: 0.0334 - val_root_mean_squared_error: 0.8517
# Epoch 53/130
# 30/30 - 3s - loss: 0.0230 - root_mean_squared_error: 0.8115 - val_loss: 0.0333 - val_root_mean_squared_error: 0.8523
# Epoch 54/130
# 30/30 - 3s - loss: 0.0228 - root_mean_squared_error: 0.8109 - val_loss: 0.0334 - val_root_mean_squared_error: 0.8523
# Epoch 55/130
# 30/30 - 3s - loss: 0.0227 - root_mean_squared_error: 0.8096 - val_loss: 0.0333 - val_root_mean_squared_error: 0.8523
# Epoch 56/130
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 30/30 - 3s - loss: 0.0226 - root_mean_squared_error: 0.8081 - val_loss: 0.0334 - val_root_mean_squared_error: 0.8542
# Epoch 57/130
# 30/30 - 3s - loss: 0.0223 - root_mean_squared_error: 0.8062 - val_loss: 0.0338 - val_root_mean_squared_error: 0.8549
# Epoch 58/130
# 30/30 - 3s - loss: 0.0222 - root_mean_squared_error: 0.8051 - val_loss: 0.0336 - val_root_mean_squared_error: 0.8543
# Epoch 59/130
# 30/30 - 3s - loss: 0.0222 - root_mean_squared_error: 0.8043 - val_loss: 0.0338 - val_root_mean_squared_error: 0.8550
# Epoch 60/130
# 30/30 - 3s - loss: 0.0220 - root_mean_squared_error: 0.8031 - val_loss: 0.0339 - val_root_mean_squared_error: 0.8564
# Epoch 61/130
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 30/30 - 3s - loss: 0.0220 - root_mean_squared_error: 0.8033 - val_loss: 0.0337 - val_root_mean_squared_error: 0.8556
# Epoch 62/130
# 30/30 - 3s - loss: 0.0219 - root_mean_squared_error: 0.8010 - val_loss: 0.0339 - val_root_mean_squared_error: 0.8569
# Epoch 63/130
# 30/30 - 3s - loss: 0.0218 - root_mean_squared_error: 0.8001 - val_loss: 0.0338 - val_root_mean_squared_error: 0.8564
# Epoch 64/130
# 30/30 - 3s - loss: 0.0217 - root_mean_squared_error: 0.7996 - val_loss: 0.0340 - val_root_mean_squared_error: 0.8574
# Epoch 65/130
# 30/30 - 3s - loss: 0.0217 - root_mean_squared_error: 0.7998 - val_loss: 0.0339 - val_root_mean_squared_error: 0.8562
# Epoch 66/130
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 30/30 - 3s - loss: 0.0216 - root_mean_squared_error: 0.7981 - val_loss: 0.0339 - val_root_mean_squared_error: 0.8570
# Epoch 67/130
# 30/30 - 3s - loss: 0.0216 - root_mean_squared_error: 0.7979 - val_loss: 0.0340 - val_root_mean_squared_error: 0.8580
# Epoch 68/130
# 30/30 - 3s - loss: 0.0216 - root_mean_squared_error: 0.7967 - val_loss: 0.0340 - val_root_mean_squared_error: 0.8577
# Epoch 69/130
# 30/30 - 3s - loss: 0.0216 - root_mean_squared_error: 0.7983 - val_loss: 0.0341 - val_root_mean_squared_error: 0.8581
# Epoch 70/130
# 30/30 - 3s - loss: 0.0215 - root_mean_squared_error: 0.7958 - val_loss: 0.0340 - val_root_mean_squared_error: 0.8581
# Epoch 71/130
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 30/30 - 3s - loss: 0.0215 - root_mean_squared_error: 0.7972 - val_loss: 0.0340 - val_root_mean_squared_error: 0.8583
# Epoch 72/130
# 30/30 - 3s - loss: 0.0215 - root_mean_squared_error: 0.7953 - val_loss: 0.0340 - val_root_mean_squared_error: 0.8584
# Epoch 73/130
# 30/30 - 3s - loss: 0.0215 - root_mean_squared_error: 0.7965 - val_loss: 0.0341 - val_root_mean_squared_error: 0.8586
# Epoch 74/130
# 30/30 - 3s - loss: 0.0214 - root_mean_squared_error: 0.7958 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8589
# Epoch 75/130
# 30/30 - 3s - loss: 0.0214 - root_mean_squared_error: 0.7956 - val_loss: 0.0341 - val_root_mean_squared_error: 0.8587
# Epoch 76/130
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 30/30 - 3s - loss: 0.0214 - root_mean_squared_error: 0.7951 - val_loss: 0.0341 - val_root_mean_squared_error: 0.8587
# Epoch 77/130
# 30/30 - 3s - loss: 0.0214 - root_mean_squared_error: 0.7948 - val_loss: 0.0341 - val_root_mean_squared_error: 0.8591
# Epoch 78/130
# 30/30 - 3s - loss: 0.0214 - root_mean_squared_error: 0.7944 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8594
# Epoch 79/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7947 - val_loss: 0.0341 - val_root_mean_squared_error: 0.8594
# Epoch 80/130
# 30/30 - 3s - loss: 0.0214 - root_mean_squared_error: 0.7937 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8593
# Epoch 81/130
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7943 - val_loss: 0.0341 - val_root_mean_squared_error: 0.8591
# Epoch 82/130
# 30/30 - 3s - loss: 0.0214 - root_mean_squared_error: 0.7950 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8593
# Epoch 83/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7943 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8594
# Epoch 84/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7942 - val_loss: 0.0341 - val_root_mean_squared_error: 0.8593
# Epoch 85/130
# 30/30 - 3s - loss: 0.0214 - root_mean_squared_error: 0.7951 - val_loss: 0.0341 - val_root_mean_squared_error: 0.8593
# Epoch 86/130
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7949 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8595
# Epoch 87/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7944 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8595
# Epoch 88/130
# 30/30 - 3s - loss: 0.0214 - root_mean_squared_error: 0.7961 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8595
# Epoch 89/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7947 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8596
# Epoch 90/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7951 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8596
# Epoch 91/130
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7938 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8597
# Epoch 92/130
# 30/30 - 3s - loss: 0.0214 - root_mean_squared_error: 0.7952 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8597
# Epoch 93/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7946 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8597
# Epoch 94/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7938 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8597
# Epoch 95/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7950 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8597
# Epoch 96/130
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7946 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8597
# Epoch 97/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7954 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8597
# Epoch 98/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7948 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8597
# Epoch 99/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7943 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 100/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7950 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 101/130
#
# Epoch 00101: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7943 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 102/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7936 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 103/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7950 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 104/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7941 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 105/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7946 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 106/130
#
# Epoch 00106: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7932 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 107/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7945 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 108/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7945 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 109/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7945 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 110/130
# 30/30 - 3s - loss: 0.0214 - root_mean_squared_error: 0.7947 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8599
# Epoch 111/130
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7945 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 112/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7941 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 113/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7938 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8599
# Epoch 114/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7943 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 115/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7950 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 116/130
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7945 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 117/130
# 30/30 - 3s - loss: 0.0212 - root_mean_squared_error: 0.7942 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 118/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7937 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8599
# Epoch 119/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7937 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8599
# Epoch 120/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7946 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8599
# Epoch 121/130
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 30/30 - 3s - loss: 0.0212 - root_mean_squared_error: 0.7937 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8599
# Epoch 122/130
# 30/30 - 3s - loss: 0.0214 - root_mean_squared_error: 0.7944 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 123/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7935 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8599
# Epoch 124/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7945 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 125/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7941 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 126/130
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7935 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8599
# Epoch 127/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7950 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 128/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7948 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 129/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7936 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# Epoch 130/130
# 30/30 - 3s - loss: 0.0213 - root_mean_squared_error: 0.7939 - val_loss: 0.0342 - val_root_mean_squared_error: 0.8598
# --------------------------------------------------
#
#
# Training fold 2
# Epoch 1/130
# 30/30 - 5s - loss: 0.1575 - root_mean_squared_error: 1.8523 - val_loss: 0.1697 - val_root_mean_squared_error: 1.6772
# Epoch 2/130
# 30/30 - 3s - loss: 0.0748 - root_mean_squared_error: 1.0438 - val_loss: 0.0886 - val_root_mean_squared_error: 0.9650
# Epoch 3/130
# 30/30 - 3s - loss: 0.0563 - root_mean_squared_error: 0.9183 - val_loss: 0.0866 - val_root_mean_squared_error: 0.9433
# Epoch 4/130
# 30/30 - 3s - loss: 0.0524 - root_mean_squared_error: 0.9110 - val_loss: 0.0830 - val_root_mean_squared_error: 0.9252
# Epoch 5/130
# 30/30 - 3s - loss: 0.0506 - root_mean_squared_error: 0.9078 - val_loss: 0.0606 - val_root_mean_squared_error: 0.8891
# Epoch 6/130
# 30/30 - 3s - loss: 0.0490 - root_mean_squared_error: 0.9042 - val_loss: 0.0614 - val_root_mean_squared_error: 0.8892
# Epoch 7/130
# 30/30 - 3s - loss: 0.0470 - root_mean_squared_error: 0.9005 - val_loss: 0.0557 - val_root_mean_squared_error: 0.8803
# Epoch 8/130
# 30/30 - 3s - loss: 0.0452 - root_mean_squared_error: 0.8976 - val_loss: 0.0564 - val_root_mean_squared_error: 0.8798
# Epoch 9/130
# 30/30 - 3s - loss: 0.0440 - root_mean_squared_error: 0.8952 - val_loss: 0.0525 - val_root_mean_squared_error: 0.8745
# Epoch 10/130
# 30/30 - 3s - loss: 0.0425 - root_mean_squared_error: 0.8919 - val_loss: 0.0473 - val_root_mean_squared_error: 0.8670
# Epoch 11/130
# 30/30 - 3s - loss: 0.0416 - root_mean_squared_error: 0.8902 - val_loss: 0.0483 - val_root_mean_squared_error: 0.8672
# Epoch 12/130
# 30/30 - 3s - loss: 0.0409 - root_mean_squared_error: 0.8888 - val_loss: 0.0423 - val_root_mean_squared_error: 0.8595
# Epoch 13/130
# 30/30 - 3s - loss: 0.0396 - root_mean_squared_error: 0.8861 - val_loss: 0.0415 - val_root_mean_squared_error: 0.8566
# Epoch 14/130
# 30/30 - 3s - loss: 0.0392 - root_mean_squared_error: 0.8855 - val_loss: 0.0413 - val_root_mean_squared_error: 0.8575
# Epoch 15/130
# 30/30 - 3s - loss: 0.0384 - root_mean_squared_error: 0.8839 - val_loss: 0.0412 - val_root_mean_squared_error: 0.8556
# Epoch 16/130
# 30/30 - 3s - loss: 0.0377 - root_mean_squared_error: 0.8821 - val_loss: 0.0407 - val_root_mean_squared_error: 0.8552
# Epoch 17/130
# 30/30 - 3s - loss: 0.0372 - root_mean_squared_error: 0.8813 - val_loss: 0.0403 - val_root_mean_squared_error: 0.8553
# Epoch 18/130
# 30/30 - 3s - loss: 0.0363 - root_mean_squared_error: 0.8792 - val_loss: 0.0377 - val_root_mean_squared_error: 0.8520
# Epoch 19/130
# 30/30 - 3s - loss: 0.0359 - root_mean_squared_error: 0.8785 - val_loss: 0.0392 - val_root_mean_squared_error: 0.8525
# Epoch 20/130
# 30/30 - 3s - loss: 0.0356 - root_mean_squared_error: 0.8772 - val_loss: 0.0380 - val_root_mean_squared_error: 0.8528
# Epoch 21/130
# 30/30 - 3s - loss: 0.0347 - root_mean_squared_error: 0.8749 - val_loss: 0.0378 - val_root_mean_squared_error: 0.8508
# Epoch 22/130
# 30/30 - 3s - loss: 0.0339 - root_mean_squared_error: 0.8725 - val_loss: 0.0379 - val_root_mean_squared_error: 0.8517
# Epoch 23/130
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 30/30 - 3s - loss: 0.0338 - root_mean_squared_error: 0.8724 - val_loss: 0.0385 - val_root_mean_squared_error: 0.8516
# Epoch 24/130
# 30/30 - 3s - loss: 0.0325 - root_mean_squared_error: 0.8687 - val_loss: 0.0370 - val_root_mean_squared_error: 0.8485
# Epoch 25/130
# 30/30 - 3s - loss: 0.0320 - root_mean_squared_error: 0.8677 - val_loss: 0.0371 - val_root_mean_squared_error: 0.8485
# Epoch 26/130
# 30/30 - 3s - loss: 0.0317 - root_mean_squared_error: 0.8662 - val_loss: 0.0371 - val_root_mean_squared_error: 0.8489
# Epoch 27/130
# 30/30 - 3s - loss: 0.0314 - root_mean_squared_error: 0.8657 - val_loss: 0.0367 - val_root_mean_squared_error: 0.8484
# Epoch 28/130
# 30/30 - 3s - loss: 0.0311 - root_mean_squared_error: 0.8647 - val_loss: 0.0364 - val_root_mean_squared_error: 0.8492
# Epoch 29/130
# 30/30 - 3s - loss: 0.0309 - root_mean_squared_error: 0.8631 - val_loss: 0.0367 - val_root_mean_squared_error: 0.8497
# Epoch 30/130
# 30/30 - 3s - loss: 0.0309 - root_mean_squared_error: 0.8627 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8474
# Epoch 31/130
# 30/30 - 3s - loss: 0.0304 - root_mean_squared_error: 0.8623 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8470
# Epoch 32/130
# 30/30 - 3s - loss: 0.0299 - root_mean_squared_error: 0.8596 - val_loss: 0.0363 - val_root_mean_squared_error: 0.8495
# Epoch 33/130
# 30/30 - 3s - loss: 0.0299 - root_mean_squared_error: 0.8589 - val_loss: 0.0363 - val_root_mean_squared_error: 0.8480
# Epoch 34/130
# 30/30 - 3s - loss: 0.0297 - root_mean_squared_error: 0.8585 - val_loss: 0.0363 - val_root_mean_squared_error: 0.8478
# Epoch 35/130
# 30/30 - 3s - loss: 0.0292 - root_mean_squared_error: 0.8565 - val_loss: 0.0365 - val_root_mean_squared_error: 0.8485
# Epoch 36/130
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 30/30 - 3s - loss: 0.0291 - root_mean_squared_error: 0.8563 - val_loss: 0.0363 - val_root_mean_squared_error: 0.8473
# Epoch 37/130
# 30/30 - 3s - loss: 0.0284 - root_mean_squared_error: 0.8528 - val_loss: 0.0360 - val_root_mean_squared_error: 0.8482
# Epoch 38/130
# 30/30 - 3s - loss: 0.0280 - root_mean_squared_error: 0.8509 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 39/130
# 30/30 - 3s - loss: 0.0278 - root_mean_squared_error: 0.8506 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8482
# Epoch 40/130
# 30/30 - 3s - loss: 0.0278 - root_mean_squared_error: 0.8496 - val_loss: 0.0360 - val_root_mean_squared_error: 0.8480
# Epoch 41/130
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 30/30 - 3s - loss: 0.0276 - root_mean_squared_error: 0.8490 - val_loss: 0.0360 - val_root_mean_squared_error: 0.8475
# Epoch 42/130
# 30/30 - 3s - loss: 0.0274 - root_mean_squared_error: 0.8482 - val_loss: 0.0360 - val_root_mean_squared_error: 0.8479
# Epoch 43/130
# 30/30 - 3s - loss: 0.0271 - root_mean_squared_error: 0.8471 - val_loss: 0.0357 - val_root_mean_squared_error: 0.8468
# Epoch 44/130
# 30/30 - 3s - loss: 0.0270 - root_mean_squared_error: 0.8458 - val_loss: 0.0360 - val_root_mean_squared_error: 0.8474
# Epoch 45/130
# 30/30 - 3s - loss: 0.0269 - root_mean_squared_error: 0.8462 - val_loss: 0.0358 - val_root_mean_squared_error: 0.8475
# Epoch 46/130
# 30/30 - 3s - loss: 0.0268 - root_mean_squared_error: 0.8444 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8469
# Epoch 47/130
# 30/30 - 3s - loss: 0.0267 - root_mean_squared_error: 0.8444 - val_loss: 0.0358 - val_root_mean_squared_error: 0.8474
# Epoch 48/130
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 30/30 - 3s - loss: 0.0267 - root_mean_squared_error: 0.8445 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8486
# Epoch 49/130
# 30/30 - 3s - loss: 0.0264 - root_mean_squared_error: 0.8425 - val_loss: 0.0360 - val_root_mean_squared_error: 0.8479
# Epoch 50/130
# 30/30 - 3s - loss: 0.0263 - root_mean_squared_error: 0.8427 - val_loss: 0.0361 - val_root_mean_squared_error: 0.8476
# Epoch 51/130
# 30/30 - 3s - loss: 0.0263 - root_mean_squared_error: 0.8412 - val_loss: 0.0361 - val_root_mean_squared_error: 0.8482
# Epoch 52/130
# 30/30 - 3s - loss: 0.0263 - root_mean_squared_error: 0.8417 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8472
# Epoch 53/130
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 30/30 - 3s - loss: 0.0262 - root_mean_squared_error: 0.8418 - val_loss: 0.0361 - val_root_mean_squared_error: 0.8478
# Epoch 54/130
# 30/30 - 3s - loss: 0.0261 - root_mean_squared_error: 0.8410 - val_loss: 0.0360 - val_root_mean_squared_error: 0.8475
# Epoch 55/130
# 30/30 - 3s - loss: 0.0260 - root_mean_squared_error: 0.8403 - val_loss: 0.0358 - val_root_mean_squared_error: 0.8473
# Epoch 56/130
# 30/30 - 3s - loss: 0.0260 - root_mean_squared_error: 0.8401 - val_loss: 0.0360 - val_root_mean_squared_error: 0.8479
# Epoch 57/130
# 30/30 - 3s - loss: 0.0259 - root_mean_squared_error: 0.8404 - val_loss: 0.0360 - val_root_mean_squared_error: 0.8475
# Epoch 58/130
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 30/30 - 3s - loss: 0.0259 - root_mean_squared_error: 0.8401 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8478
# Epoch 59/130
# 30/30 - 3s - loss: 0.0258 - root_mean_squared_error: 0.8393 - val_loss: 0.0358 - val_root_mean_squared_error: 0.8475
# Epoch 60/130
# 30/30 - 3s - loss: 0.0258 - root_mean_squared_error: 0.8403 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8475
# Epoch 61/130
# 30/30 - 3s - loss: 0.0258 - root_mean_squared_error: 0.8391 - val_loss: 0.0358 - val_root_mean_squared_error: 0.8477
# Epoch 62/130
# 30/30 - 3s - loss: 0.0258 - root_mean_squared_error: 0.8391 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8473
# Epoch 63/130
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 30/30 - 3s - loss: 0.0258 - root_mean_squared_error: 0.8389 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8478
# Epoch 64/130
# 30/30 - 3s - loss: 0.0258 - root_mean_squared_error: 0.8389 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 65/130
# 30/30 - 3s - loss: 0.0258 - root_mean_squared_error: 0.8394 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 66/130
# 30/30 - 3s - loss: 0.0258 - root_mean_squared_error: 0.8388 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 67/130
# 30/30 - 3s - loss: 0.0258 - root_mean_squared_error: 0.8386 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 68/130
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8390 - val_loss: 0.0360 - val_root_mean_squared_error: 0.8477
# Epoch 69/130
# 30/30 - 3s - loss: 0.0258 - root_mean_squared_error: 0.8385 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 70/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8387 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 71/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8390 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 72/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8382 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 73/130
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8382 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 74/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8383 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 75/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8380 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 76/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8379 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 77/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8382 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 78/130
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8380 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 79/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8382 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 80/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8375 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 81/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8386 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 82/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8382 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 83/130
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8380 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 84/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8388 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 85/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8383 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 86/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8388 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 87/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8380 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 88/130
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8377 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 89/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8384 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 90/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8383 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 91/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8386 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 92/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8380 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 93/130
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8379 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 94/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8388 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 95/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8377 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 96/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8386 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 97/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8382 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 98/130
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8380 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 99/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8379 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 100/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8378 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 101/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8378 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 102/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8380 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 103/130
#
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8382 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 104/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8380 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 105/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8382 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 106/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8384 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 107/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8387 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 108/130
#
# Epoch 00108: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8381 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 109/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8384 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 110/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8377 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 111/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8383 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 112/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8387 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 113/130
#
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8391 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 114/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8381 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 115/130
# 30/30 - 3s - loss: 0.0258 - root_mean_squared_error: 0.8380 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 116/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8379 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 117/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8381 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 118/130
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8380 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 119/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8374 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 120/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8381 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 121/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8382 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 122/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8384 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 123/130
#
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8384 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 124/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8378 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# Epoch 125/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8382 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 126/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8381 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 127/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8381 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 128/130
#
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.8382 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 129/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8379 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8476
# Epoch 130/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8381 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8477
# --------------------------------------------------
#
#
# Training fold 3
# Epoch 1/130
# 30/30 - 5s - loss: 0.1546 - root_mean_squared_error: 1.9428 - val_loss: 0.1743 - val_root_mean_squared_error: 1.9796
# Epoch 2/130
# 30/30 - 3s - loss: 0.0760 - root_mean_squared_error: 1.0631 - val_loss: 0.0876 - val_root_mean_squared_error: 1.1016
# Epoch 3/130
# 30/30 - 3s - loss: 0.0560 - root_mean_squared_error: 0.8797 - val_loss: 0.0852 - val_root_mean_squared_error: 1.0822
# Epoch 4/130
# 30/30 - 3s - loss: 0.0521 - root_mean_squared_error: 0.8714 - val_loss: 0.0635 - val_root_mean_squared_error: 1.0373
# Epoch 5/130
# 30/30 - 3s - loss: 0.0499 - root_mean_squared_error: 0.8680 - val_loss: 0.0626 - val_root_mean_squared_error: 1.0352
# Epoch 6/130
# 30/30 - 3s - loss: 0.0480 - root_mean_squared_error: 0.8641 - val_loss: 0.0570 - val_root_mean_squared_error: 1.0269
# Epoch 7/130
# 30/30 - 3s - loss: 0.0463 - root_mean_squared_error: 0.8613 - val_loss: 0.0582 - val_root_mean_squared_error: 1.0288
# Epoch 8/130
# 30/30 - 3s - loss: 0.0448 - root_mean_squared_error: 0.8574 - val_loss: 0.0520 - val_root_mean_squared_error: 1.0206
# Epoch 9/130
# 30/30 - 3s - loss: 0.0434 - root_mean_squared_error: 0.8546 - val_loss: 0.0500 - val_root_mean_squared_error: 1.0190
# Epoch 10/130
# 30/30 - 3s - loss: 0.0425 - root_mean_squared_error: 0.8532 - val_loss: 0.0506 - val_root_mean_squared_error: 1.0197
# Epoch 11/130
# 30/30 - 3s - loss: 0.0415 - root_mean_squared_error: 0.8512 - val_loss: 0.0461 - val_root_mean_squared_error: 1.0118
# Epoch 12/130
# 30/30 - 3s - loss: 0.0406 - root_mean_squared_error: 0.8487 - val_loss: 0.0461 - val_root_mean_squared_error: 1.0110
# Epoch 13/130
# 30/30 - 3s - loss: 0.0394 - root_mean_squared_error: 0.8465 - val_loss: 0.0429 - val_root_mean_squared_error: 1.0073
# Epoch 14/130
# 30/30 - 3s - loss: 0.0390 - root_mean_squared_error: 0.8456 - val_loss: 0.0419 - val_root_mean_squared_error: 1.0060
# Epoch 15/130
# 30/30 - 3s - loss: 0.0383 - root_mean_squared_error: 0.8442 - val_loss: 0.0413 - val_root_mean_squared_error: 1.0037
# Epoch 16/130
# 30/30 - 3s - loss: 0.0384 - root_mean_squared_error: 0.8440 - val_loss: 0.0414 - val_root_mean_squared_error: 1.0045
# Epoch 17/130
# 30/30 - 3s - loss: 0.0377 - root_mean_squared_error: 0.8431 - val_loss: 0.0409 - val_root_mean_squared_error: 1.0034
# Epoch 18/130
# 30/30 - 3s - loss: 0.0364 - root_mean_squared_error: 0.8401 - val_loss: 0.0408 - val_root_mean_squared_error: 1.0053
# Epoch 19/130
# 30/30 - 3s - loss: 0.0360 - root_mean_squared_error: 0.8385 - val_loss: 0.0397 - val_root_mean_squared_error: 1.0023
# Epoch 20/130
# 30/30 - 3s - loss: 0.0353 - root_mean_squared_error: 0.8370 - val_loss: 0.0391 - val_root_mean_squared_error: 1.0025
# Epoch 21/130
# 30/30 - 3s - loss: 0.0345 - root_mean_squared_error: 0.8353 - val_loss: 0.0395 - val_root_mean_squared_error: 1.0034
# Epoch 22/130
# 30/30 - 3s - loss: 0.0348 - root_mean_squared_error: 0.8354 - val_loss: 0.0396 - val_root_mean_squared_error: 1.0034
# Epoch 23/130
# 30/30 - 3s - loss: 0.0338 - root_mean_squared_error: 0.8331 - val_loss: 0.0388 - val_root_mean_squared_error: 1.0023
# Epoch 24/130
# 30/30 - 3s - loss: 0.0337 - root_mean_squared_error: 0.8325 - val_loss: 0.0402 - val_root_mean_squared_error: 1.0027
# Epoch 25/130
# 30/30 - 3s - loss: 0.0328 - root_mean_squared_error: 0.8307 - val_loss: 0.0385 - val_root_mean_squared_error: 1.0018
# Epoch 26/130
# 30/30 - 3s - loss: 0.0324 - root_mean_squared_error: 0.8293 - val_loss: 0.0385 - val_root_mean_squared_error: 1.0013
# Epoch 27/130
# 30/30 - 3s - loss: 0.0319 - root_mean_squared_error: 0.8272 - val_loss: 0.0387 - val_root_mean_squared_error: 1.0006
# Epoch 28/130
# 30/30 - 3s - loss: 0.0316 - root_mean_squared_error: 0.8259 - val_loss: 0.0379 - val_root_mean_squared_error: 1.0006
# Epoch 29/130
# 30/30 - 3s - loss: 0.0310 - root_mean_squared_error: 0.8239 - val_loss: 0.0405 - val_root_mean_squared_error: 1.0056
# Epoch 30/130
# 30/30 - 3s - loss: 0.0307 - root_mean_squared_error: 0.8231 - val_loss: 0.0379 - val_root_mean_squared_error: 1.0000
# Epoch 31/130
# 30/30 - 3s - loss: 0.0303 - root_mean_squared_error: 0.8207 - val_loss: 0.0397 - val_root_mean_squared_error: 1.0016
# Epoch 32/130
# 30/30 - 3s - loss: 0.0300 - root_mean_squared_error: 0.8201 - val_loss: 0.0387 - val_root_mean_squared_error: 1.0010
# Epoch 33/130
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 30/30 - 3s - loss: 0.0295 - root_mean_squared_error: 0.8184 - val_loss: 0.0380 - val_root_mean_squared_error: 1.0000
# Epoch 34/130
# 30/30 - 3s - loss: 0.0287 - root_mean_squared_error: 0.8145 - val_loss: 0.0388 - val_root_mean_squared_error: 1.0014
# Epoch 35/130
# 30/30 - 3s - loss: 0.0282 - root_mean_squared_error: 0.8131 - val_loss: 0.0373 - val_root_mean_squared_error: 0.9993
# Epoch 36/130
# 30/30 - 3s - loss: 0.0278 - root_mean_squared_error: 0.8105 - val_loss: 0.0374 - val_root_mean_squared_error: 1.0002
# Epoch 37/130
# 30/30 - 3s - loss: 0.0276 - root_mean_squared_error: 0.8101 - val_loss: 0.0378 - val_root_mean_squared_error: 1.0000
# Epoch 38/130
# 30/30 - 3s - loss: 0.0274 - root_mean_squared_error: 0.8084 - val_loss: 0.0378 - val_root_mean_squared_error: 0.9993
# Epoch 39/130
# 30/30 - 3s - loss: 0.0272 - root_mean_squared_error: 0.8078 - val_loss: 0.0378 - val_root_mean_squared_error: 0.9995
# Epoch 40/130
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 30/30 - 3s - loss: 0.0271 - root_mean_squared_error: 0.8075 - val_loss: 0.0384 - val_root_mean_squared_error: 1.0036
# Epoch 41/130
# 30/30 - 3s - loss: 0.0265 - root_mean_squared_error: 0.8047 - val_loss: 0.0380 - val_root_mean_squared_error: 1.0004
# Epoch 42/130
# 30/30 - 3s - loss: 0.0260 - root_mean_squared_error: 0.8020 - val_loss: 0.0376 - val_root_mean_squared_error: 1.0002
# Epoch 43/130
# 30/30 - 3s - loss: 0.0258 - root_mean_squared_error: 0.8000 - val_loss: 0.0380 - val_root_mean_squared_error: 1.0019
# Epoch 44/130
# 30/30 - 3s - loss: 0.0256 - root_mean_squared_error: 0.7992 - val_loss: 0.0385 - val_root_mean_squared_error: 1.0020
# Epoch 45/130
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 30/30 - 3s - loss: 0.0255 - root_mean_squared_error: 0.7985 - val_loss: 0.0379 - val_root_mean_squared_error: 1.0006
# Epoch 46/130
# 30/30 - 3s - loss: 0.0251 - root_mean_squared_error: 0.7969 - val_loss: 0.0378 - val_root_mean_squared_error: 1.0016
# Epoch 47/130
# 30/30 - 3s - loss: 0.0251 - root_mean_squared_error: 0.7954 - val_loss: 0.0382 - val_root_mean_squared_error: 1.0021
# Epoch 48/130
# 30/30 - 3s - loss: 0.0249 - root_mean_squared_error: 0.7949 - val_loss: 0.0380 - val_root_mean_squared_error: 1.0025
# Epoch 49/130
# 30/30 - 3s - loss: 0.0248 - root_mean_squared_error: 0.7937 - val_loss: 0.0377 - val_root_mean_squared_error: 1.0016
# Epoch 50/130
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 30/30 - 3s - loss: 0.0247 - root_mean_squared_error: 0.7925 - val_loss: 0.0376 - val_root_mean_squared_error: 1.0015
# Epoch 51/130
# 30/30 - 3s - loss: 0.0246 - root_mean_squared_error: 0.7918 - val_loss: 0.0378 - val_root_mean_squared_error: 1.0024
# Epoch 52/130
# 30/30 - 3s - loss: 0.0244 - root_mean_squared_error: 0.7907 - val_loss: 0.0380 - val_root_mean_squared_error: 1.0023
# Epoch 53/130
# 30/30 - 3s - loss: 0.0244 - root_mean_squared_error: 0.7898 - val_loss: 0.0378 - val_root_mean_squared_error: 1.0025
# Epoch 54/130
# 30/30 - 3s - loss: 0.0243 - root_mean_squared_error: 0.7894 - val_loss: 0.0380 - val_root_mean_squared_error: 1.0022
# Epoch 55/130
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 30/30 - 3s - loss: 0.0242 - root_mean_squared_error: 0.7884 - val_loss: 0.0380 - val_root_mean_squared_error: 1.0021
# Epoch 56/130
# 30/30 - 3s - loss: 0.0241 - root_mean_squared_error: 0.7883 - val_loss: 0.0380 - val_root_mean_squared_error: 1.0025
# Epoch 57/130
# 30/30 - 3s - loss: 0.0240 - root_mean_squared_error: 0.7864 - val_loss: 0.0381 - val_root_mean_squared_error: 1.0030
# Epoch 58/130
# 30/30 - 3s - loss: 0.0240 - root_mean_squared_error: 0.7873 - val_loss: 0.0381 - val_root_mean_squared_error: 1.0029
# Epoch 59/130
# 30/30 - 3s - loss: 0.0240 - root_mean_squared_error: 0.7867 - val_loss: 0.0381 - val_root_mean_squared_error: 1.0027
# Epoch 60/130
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 30/30 - 3s - loss: 0.0239 - root_mean_squared_error: 0.7865 - val_loss: 0.0381 - val_root_mean_squared_error: 1.0023
# Epoch 61/130
# 30/30 - 3s - loss: 0.0239 - root_mean_squared_error: 0.7851 - val_loss: 0.0381 - val_root_mean_squared_error: 1.0028
# Epoch 62/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.7857 - val_loss: 0.0380 - val_root_mean_squared_error: 1.0025
# Epoch 63/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.7855 - val_loss: 0.0381 - val_root_mean_squared_error: 1.0030
# Epoch 64/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.7852 - val_loss: 0.0381 - val_root_mean_squared_error: 1.0028
# Epoch 65/130
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.7854 - val_loss: 0.0381 - val_root_mean_squared_error: 1.0029
# Epoch 66/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.7845 - val_loss: 0.0381 - val_root_mean_squared_error: 1.0032
# Epoch 67/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.7843 - val_loss: 0.0382 - val_root_mean_squared_error: 1.0033
# Epoch 68/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.7848 - val_loss: 0.0381 - val_root_mean_squared_error: 1.0029
# Epoch 69/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.7836 - val_loss: 0.0381 - val_root_mean_squared_error: 1.0032
# Epoch 70/130
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.7843 - val_loss: 0.0382 - val_root_mean_squared_error: 1.0033
# Epoch 71/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.7838 - val_loss: 0.0381 - val_root_mean_squared_error: 1.0030
# Epoch 72/130
# 30/30 - 3s - loss: 0.0236 - root_mean_squared_error: 0.7831 - val_loss: 0.0381 - val_root_mean_squared_error: 1.0030
# Epoch 73/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.7845 - val_loss: 0.0382 - val_root_mean_squared_error: 1.0031
# Epoch 74/130
# 30/30 - 3s - loss: 0.0236 - root_mean_squared_error: 0.7831 - val_loss: 0.0382 - val_root_mean_squared_error: 1.0032
# Epoch 75/130
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 30/30 - 3s - loss: 0.0236 - root_mean_squared_error: 0.7834 - val_loss: 0.0382 - val_root_mean_squared_error: 1.0032
# Epoch 76/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.7836 - val_loss: 0.0382 - val_root_mean_squared_error: 1.0032
# Epoch 77/130
# 30/30 - 3s - loss: 0.0236 - root_mean_squared_error: 0.7834 - val_loss: 0.0382 - val_root_mean_squared_error: 1.0032
# Epoch 78/130
# 30/30 - 3s - loss: 0.0236 - root_mean_squared_error: 0.7831 - val_loss: 0.0382 - val_root_mean_squared_error: 1.0032
# Epoch 79/130
# ...
# Epoch 21/130
# 30/30 - 3s - loss: 0.0355 - root_mean_squared_error: 0.8808 - val_loss: 0.0389 - val_root_mean_squared_error: 0.8392
# Epoch 22/130
# 30/30 - 3s - loss: 0.0352 - root_mean_squared_error: 0.8801 - val_loss: 0.0377 - val_root_mean_squared_error: 0.8361
# Epoch 23/130
# 30/30 - 3s - loss: 0.0344 - root_mean_squared_error: 0.8788 - val_loss: 0.0370 - val_root_mean_squared_error: 0.8349
# Epoch 24/130
# 30/30 - 3s - loss: 0.0343 - root_mean_squared_error: 0.8776 - val_loss: 0.0390 - val_root_mean_squared_error: 0.8415
# Epoch 25/130
# 30/30 - 3s - loss: 0.0335 - root_mean_squared_error: 0.8767 - val_loss: 0.0379 - val_root_mean_squared_error: 0.8376
# Epoch 26/130
# 30/30 - 3s - loss: 0.0331 - root_mean_squared_error: 0.8751 - val_loss: 0.0368 - val_root_mean_squared_error: 0.8353
# Epoch 27/130
# 30/30 - 3s - loss: 0.0324 - root_mean_squared_error: 0.8725 - val_loss: 0.0368 - val_root_mean_squared_error: 0.8356
# Epoch 28/130
# 30/30 - 3s - loss: 0.0330 - root_mean_squared_error: 0.8752 - val_loss: 0.0382 - val_root_mean_squared_error: 0.8380
# Epoch 29/130
# 30/30 - 3s - loss: 0.0320 - root_mean_squared_error: 0.8718 - val_loss: 0.0358 - val_root_mean_squared_error: 0.8330
# Epoch 30/130
# 30/30 - 3s - loss: 0.0314 - root_mean_squared_error: 0.8700 - val_loss: 0.0363 - val_root_mean_squared_error: 0.8330
# Epoch 31/130
# 30/30 - 3s - loss: 0.0308 - root_mean_squared_error: 0.8686 - val_loss: 0.0364 - val_root_mean_squared_error: 0.8322
# Epoch 32/130
# 30/30 - 3s - loss: 0.0306 - root_mean_squared_error: 0.8670 - val_loss: 0.0358 - val_root_mean_squared_error: 0.8311
# Epoch 33/130
# 30/30 - 3s - loss: 0.0303 - root_mean_squared_error: 0.8653 - val_loss: 0.0370 - val_root_mean_squared_error: 0.8330
# Epoch 34/130
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 30/30 - 3s - loss: 0.0299 - root_mean_squared_error: 0.8644 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8320
# Epoch 35/130
# 30/30 - 3s - loss: 0.0289 - root_mean_squared_error: 0.8607 - val_loss: 0.0356 - val_root_mean_squared_error: 0.8283
# Epoch 36/130
# 30/30 - 3s - loss: 0.0285 - root_mean_squared_error: 0.8592 - val_loss: 0.0358 - val_root_mean_squared_error: 0.8315
# Epoch 37/130
# 30/30 - 3s - loss: 0.0284 - root_mean_squared_error: 0.8585 - val_loss: 0.0357 - val_root_mean_squared_error: 0.8302
# Epoch 38/130
# 30/30 - 3s - loss: 0.0280 - root_mean_squared_error: 0.8568 - val_loss: 0.0356 - val_root_mean_squared_error: 0.8293
# Epoch 39/130
# 30/30 - 3s - loss: 0.0279 - root_mean_squared_error: 0.8552 - val_loss: 0.0357 - val_root_mean_squared_error: 0.8308
# Epoch 40/130
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 30/30 - 3s - loss: 0.0277 - root_mean_squared_error: 0.8556 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8296
# Epoch 41/130
# 30/30 - 3s - loss: 0.0272 - root_mean_squared_error: 0.8518 - val_loss: 0.0356 - val_root_mean_squared_error: 0.8306
# Epoch 42/130
# 30/30 - 3s - loss: 0.0269 - root_mean_squared_error: 0.8513 - val_loss: 0.0355 - val_root_mean_squared_error: 0.8291
# Epoch 43/130
# 30/30 - 3s - loss: 0.0267 - root_mean_squared_error: 0.8495 - val_loss: 0.0355 - val_root_mean_squared_error: 0.8289
# Epoch 44/130
# 30/30 - 3s - loss: 0.0266 - root_mean_squared_error: 0.8493 - val_loss: 0.0356 - val_root_mean_squared_error: 0.8301
# Epoch 45/130
# 30/30 - 3s - loss: 0.0264 - root_mean_squared_error: 0.8476 - val_loss: 0.0357 - val_root_mean_squared_error: 0.8296
# Epoch 46/130
# 30/30 - 3s - loss: 0.0263 - root_mean_squared_error: 0.8465 - val_loss: 0.0353 - val_root_mean_squared_error: 0.8281
# Epoch 47/130
# 30/30 - 3s - loss: 0.0262 - root_mean_squared_error: 0.8457 - val_loss: 0.0357 - val_root_mean_squared_error: 0.8288
# Epoch 48/130
# 30/30 - 3s - loss: 0.0261 - root_mean_squared_error: 0.8453 - val_loss: 0.0358 - val_root_mean_squared_error: 0.8294
# Epoch 49/130
# 30/30 - 3s - loss: 0.0258 - root_mean_squared_error: 0.8433 - val_loss: 0.0360 - val_root_mean_squared_error: 0.8303
# Epoch 50/130
# 30/30 - 3s - loss: 0.0257 - root_mean_squared_error: 0.8425 - val_loss: 0.0357 - val_root_mean_squared_error: 0.8298
# Epoch 51/130
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 30/30 - 3s - loss: 0.0259 - root_mean_squared_error: 0.8428 - val_loss: 0.0357 - val_root_mean_squared_error: 0.8291
# Epoch 52/130
# 30/30 - 3s - loss: 0.0253 - root_mean_squared_error: 0.8403 - val_loss: 0.0365 - val_root_mean_squared_error: 0.8312
# Epoch 53/130
# 30/30 - 3s - loss: 0.0251 - root_mean_squared_error: 0.8373 - val_loss: 0.0360 - val_root_mean_squared_error: 0.8311
# Epoch 54/130
# 30/30 - 3s - loss: 0.0251 - root_mean_squared_error: 0.8386 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8314
# Epoch 55/130
# 30/30 - 3s - loss: 0.0249 - root_mean_squared_error: 0.8363 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8330
# Epoch 56/130
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 30/30 - 3s - loss: 0.0248 - root_mean_squared_error: 0.8354 - val_loss: 0.0357 - val_root_mean_squared_error: 0.8299
# Epoch 57/130
# 30/30 - 3s - loss: 0.0246 - root_mean_squared_error: 0.8336 - val_loss: 0.0358 - val_root_mean_squared_error: 0.8304
# Epoch 58/130
# 30/30 - 3s - loss: 0.0246 - root_mean_squared_error: 0.8340 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8314
# Epoch 59/130
# 30/30 - 3s - loss: 0.0244 - root_mean_squared_error: 0.8327 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8314
# Epoch 60/130
# 30/30 - 3s - loss: 0.0244 - root_mean_squared_error: 0.8325 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8322
# Epoch 61/130
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 30/30 - 3s - loss: 0.0243 - root_mean_squared_error: 0.8312 - val_loss: 0.0360 - val_root_mean_squared_error: 0.8314
# Epoch 62/130
# 30/30 - 3s - loss: 0.0242 - root_mean_squared_error: 0.8310 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8322
# Epoch 63/130
# 30/30 - 3s - loss: 0.0242 - root_mean_squared_error: 0.8301 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8312
# Epoch 64/130
# 30/30 - 3s - loss: 0.0241 - root_mean_squared_error: 0.8300 - val_loss: 0.0360 - val_root_mean_squared_error: 0.8319
# Epoch 65/130
# 30/30 - 3s - loss: 0.0241 - root_mean_squared_error: 0.8301 - val_loss: 0.0359 - val_root_mean_squared_error: 0.8313
# Epoch 66/130
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 30/30 - 3s - loss: 0.0240 - root_mean_squared_error: 0.8292 - val_loss: 0.0361 - val_root_mean_squared_error: 0.8321
# Epoch 67/130
# 30/30 - 3s - loss: 0.0240 - root_mean_squared_error: 0.8290 - val_loss: 0.0361 - val_root_mean_squared_error: 0.8321
# Epoch 68/130
# 30/30 - 3s - loss: 0.0240 - root_mean_squared_error: 0.8288 - val_loss: 0.0361 - val_root_mean_squared_error: 0.8321
# Epoch 69/130
# 30/30 - 3s - loss: 0.0240 - root_mean_squared_error: 0.8287 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8327
# Epoch 70/130
# 30/30 - 3s - loss: 0.0240 - root_mean_squared_error: 0.8285 - val_loss: 0.0361 - val_root_mean_squared_error: 0.8323
# Epoch 71/130
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 30/30 - 3s - loss: 0.0239 - root_mean_squared_error: 0.8278 - val_loss: 0.0361 - val_root_mean_squared_error: 0.8324
# Epoch 72/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8273 - val_loss: 0.0361 - val_root_mean_squared_error: 0.8324
# Epoch 73/130
# 30/30 - 3s - loss: 0.0239 - root_mean_squared_error: 0.8277 - val_loss: 0.0361 - val_root_mean_squared_error: 0.8323
# Epoch 74/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8272 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8326
# Epoch 75/130
# 30/30 - 3s - loss: 0.0239 - root_mean_squared_error: 0.8269 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8327
# Epoch 76/130
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8270 - val_loss: 0.0361 - val_root_mean_squared_error: 0.8325
# Epoch 77/130
# 30/30 - 3s - loss: 0.0239 - root_mean_squared_error: 0.8271 - val_loss: 0.0361 - val_root_mean_squared_error: 0.8328
# Epoch 78/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8266 - val_loss: 0.0361 - val_root_mean_squared_error: 0.8327
# Epoch 79/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8270 - val_loss: 0.0361 - val_root_mean_squared_error: 0.8327
# Epoch 80/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8265 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 81/130
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8272 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8328
# Epoch 82/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8274 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8327
# Epoch 83/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8264 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8327
# Epoch 84/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8268 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8328
# Epoch 85/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8268 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8327
# Epoch 86/130
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8264 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8328
# Epoch 87/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8258 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8328
# Epoch 88/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8265 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 89/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8256 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 90/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8267 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 91/130
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8275 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 92/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8257 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 93/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8262 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 94/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8261 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 95/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8270 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 96/130
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8265 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 97/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8265 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 98/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8261 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 99/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8272 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 100/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8261 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 101/130
#
# Epoch 00101: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8270 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 102/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8267 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 103/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8257 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 104/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8265 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 105/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8256 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 106/130
#
# Epoch 00106: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8263 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 107/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8263 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 108/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8271 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 109/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8261 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 110/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8273 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 111/130
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8256 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 112/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8270 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 113/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8263 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 114/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8261 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 115/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8261 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 116/130
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8264 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 117/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8263 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 118/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8259 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 119/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8262 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 120/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8260 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 121/130
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8261 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 122/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8264 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 123/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8262 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 124/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8258 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 125/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8268 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 126/130
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8258 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 127/130
# 30/30 - 3s - loss: 0.0238 - root_mean_squared_error: 0.8269 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 128/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8260 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 129/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8264 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# Epoch 130/130
# 30/30 - 3s - loss: 0.0237 - root_mean_squared_error: 0.8262 - val_loss: 0.0362 - val_root_mean_squared_error: 0.8329
# --------------------------------------------------
#
#
# Our out of folds mean columnwise root mean squared error is 0.8333189939839716

# %%
# Function to get our predictions in the correct format
def inference_format(public_test_df, public_preds, private_test_df, private_preds, target_cols):
    predictions = []
    for test, preds in [(public_test_df, public_preds), (private_test_df, private_preds)]:
        for index, uid in enumerate(test['id']):
            single_pred = preds[index]
            single_df = pd.DataFrame(single_pred, columns = target_cols)
            # Add id
            single_df['id_seqpos'] = [f'{uid}_{x}' for x in range(single_df.shape[0])]
            predictions.append(single_df)
            
    predictions = pd.concat(predictions)
    return predictions

# Get our predictions in the correct format
predictions = inference_format(public_test_df, public_preds, private_test_df, private_preds, target_cols)
# Sanity check
submission = sample_sub[['id_seqpos']].merge(predictions, on = ['id_seqpos'])
submission.to_csv('submission.csv', index = False)
print('Submission saved')
submission.head()
# Out:
# Submission saved
#         id_seqpos  reactivity  deg_Mg_pH10  deg_pH10  deg_Mg_50C   deg_50C
# 0  id_00073f8be_0    0.693844     0.687874  1.979116    0.553509  0.789553
# 1  id_00073f8be_1    2.057277     3.195342  4.324982    3.255920  2.704052
# 2  id_00073f8be_2    1.336556     0.518475  0.775098    0.656889  0.740439
# 3  id_00073f8be_3    1.223201     1.041654  1.241629    1.564011  1.606680
# 4  id_00073f8be_4    0.810389     0.597832  0.662505    0.846010  0.894738

# %%
model = build_model()
model.load_weights(f'fold_{1}.h5')
oof_preds = model.predict(train_inputs)

# %%
oof_preds = pd.DataFrame(oof_preds.reshape(2400* 68, 5), columns=['reactivity', 'deg_Mg_pH10', 'deg_pH10', 'deg_Mg_50C', 'deg_50C']).reset_index()
oof_preds
# Out:
#          index  reactivity  deg_Mg_pH10  deg_pH10  deg_Mg_50C   deg_50C
# 0            0    0.588574     0.635067  2.026857    0.534996  0.732166
# 1            1    2.198969     2.939623  4.190956    3.268068  2.752833
# 2            2    1.186700     0.283450  0.393842    0.345079  0.605969
# 3            3    0.919691     1.193306  1.128324    1.633060  1.173876
# 4            4    0.681619     0.504424  0.550982    0.718609  0.770387
# ...        ...         ...          ...       ...         ...       ...
# 163195  163195    0.021524     0.546901  0.320177    0.315564  0.229524
# 163196  163196    0.054928     0.247885  0.118270    0.139528  0.148819
# 163197  163197    0.029847     0.234294  0.151654    0.145747  0.164676
# 163198  163198    0.043874     0.397568  0.272057    0.273576  0.213863
# 163199  163199    0.109726     0.517865  0.563416    0.257899  0.370516
#
# [163200 rows x 6 columns]

# %%
lables = pd.DataFrame(train_labels.reshape(2400* 68, 5), columns=['reactivity', 'deg_Mg_pH10', 'deg_pH10', 'deg_Mg_50C', 'deg_50C']).reset_index()
lables
# Out:
#          index  reactivity  deg_Mg_pH10  deg_pH10  deg_Mg_50C  deg_50C
# 0            0      0.3297       0.7556    2.3375      0.3581   0.6382
# 1            1      1.5693       2.9830    3.5060      2.9683   3.4773
# 2            2      1.1227       0.2526    0.3008      0.2589   0.9988
# 3            3      0.8686       1.3789    1.0108      1.4552   1.3228
# 4            4      0.7217       0.6376    0.2635      0.7244   0.7877
# ...        ...         ...          ...       ...         ...      ...
# 163195  163195      0.0272       0.5059    0.4998      0.2870   0.1820
# 163196  163196      0.0382       0.2025    0.3057      0.2022   0.2038
# 163197  163197      0.0381       0.1827    0.1642      0.2047   0.1120
# 163198  163198     -0.0066       0.3261    0.1654      0.2447   0.1186
# 163199  163199      0.0706       0.4529    0.4840      0.1802   0.3013
#
# [163200 rows x 6 columns]

# %%
oof_preds.to_csv('oof_preds_wavenet.csv', index = False)
lables.to_csv('train_labels.csv', index = False)
